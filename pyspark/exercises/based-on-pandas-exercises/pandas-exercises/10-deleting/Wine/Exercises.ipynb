# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
FILEPATH = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'

wine = pd.read_csv(FILEPATH)
print(wine.info())
wine.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       177 non-null    int64
#  1   14.23   177 non-null    float64
#  2   1.71    177 non-null    float64
#  3   2.43    177 non-null    float64
#  4   15.6    177 non-null    float64
#  5   127     177 non-null    int64
#  6   2.8     177 non-null    float64
#  7   3.06    177 non-null    float64
#  8   .28     177 non-null    float64
#  9   2.29    177 non-null    float64
#  10  5.64    177 non-null    float64
#  11  1.04    177 non-null    float64
#  12  3.92    177 non-null    float64
#  13  1065    177 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.5 KB
# None
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# ...

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
columns_positions_to_delete = [0, 3, 6, 8, 10, 12, 13]
wine = wine.drop(columns=wine.columns[columns_positions_to_delete])
wine.head()
# Out:
#    14.23  1.71  15.6  127  3.06  2.29  1.04
# 0  13.20  1.78  11.2  100  2.76  1.28  1.05
# 1  13.16  2.36  18.6  101  3.24  2.81  1.03
# 2  14.37  1.95  16.8  113  3.49  2.18  0.86
# 3  13.24  2.59  21.0  118  2.69  1.82  1.04
# 4  14.20  1.76  15.2  112  3.39  1.97  1.05

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
renaming_mapper = {
    '14.23': 'alcohol',
    '1.71': 'malic_acid',
    '15.6': 'alcalinity_of_ash',
    '127': 'magnesium',
    '3.06': 'flavanoids',
    '2.29': 'proanthocyanins',
    '1.04': 'hue'
}
wine = wine.rename(columns=renaming_mapper)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.20        1.78               11.2        100        2.76
# 1    13.16        2.36               18.6        101        3.24
# 2    14.37        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
wine.iloc[:3, 0] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2        100        2.76
# 1      NaN        2.36               18.6        101        3.24
# 2      NaN        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.iloc[3:5, 3] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2      100.0        2.76
# 1      NaN        2.36               18.6      101.0        3.24
# 2      NaN        1.95               16.8      113.0        3.49
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2        NaN        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine['alcohol'].fillna(10, inplace=True)
wine['magnesium'].fillna(10, inplace=True)

wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00        1.78               11.2      100.0        2.76
# 1    10.00        2.36               18.6      101.0        3.24
# 2    10.00        1.95               16.8      113.0        3.49
# 3    13.24        2.59               21.0       10.0        2.69
# 4    14.20        1.76               15.2       10.0        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
print(wine.isna().sum())
print(wine.isna().sum(axis=1))
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 172    0
# 173    0
# 174    0
# 175    0
# 176    0
# Length: 177, dtype: int64

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
positions = np.random.randint(low=0, high=10, size=10)
positions
# Out:
# array([9, 3, 1, 5, 7, 5, 8, 8, 0, 7])

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
wine.iloc[positions, 0] = np.nan
wine.head(10)
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2      100.0        2.76
# 1      NaN        2.36               18.6      101.0        3.24
# 2    10.00        1.95               16.8      113.0        3.49
# 3      NaN        2.59               21.0       10.0        2.69
# 4    14.20        1.76               15.2       10.0        3.39
# 5      NaN        1.87               14.6       96.0        2.52
# 6    14.06        2.15               17.6      121.0        2.51
# 7      NaN        1.64               14.0       97.0        2.98
# 8      NaN        1.35               16.0       98.0        3.15
# 9      NaN        2.16               18.0      105.0        3.32
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05
# 5             1.98  1.02
# 6             1.25  1.06
# 7             1.98  1.08
# ...

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
wine.isna().sum()
# Out:
# alcohol              7
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
wine = wine.dropna()
wine.head(10)
# Out:
#     alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 2     10.00        1.95               16.8      113.0        3.49
# 4     14.20        1.76               15.2       10.0        3.39
# 6     14.06        2.15               17.6      121.0        2.51
# 10    14.12        1.48               16.8       95.0        2.43
# 11    13.75        1.73               16.0       89.0        2.76
# 12    14.75        1.73               11.4       91.0        3.69
# 13    14.38        1.87               12.0      102.0        3.64
# 14    13.63        1.81               17.2      112.0        2.91
# 15    14.30        1.92               20.0      120.0        3.14
# 16    13.83        1.57               20.0      115.0        3.40
#
#     proanthocyanins   hue
# 2              2.18  0.86
# 4              1.97  1.05
# 6              1.25  1.06
# 10             1.57  1.17
# 11             1.81  1.15
# 12             2.81  1.25
# 13             2.96  1.20
# ...

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
wine['alcohol'].dropna()
# Out:
# 2      10.00
# 4      14.20
# 6      14.06
# 10     14.12
# 11     13.75
#        ...
# 172    13.71
# 173    13.40
# 174    13.27
# 175    13.17
# 176    14.13
# Name: alcohol, Length: 170, dtype: float64

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
wine = wine.reset_index(drop=True)
wine.head(10)
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00        1.95               16.8      113.0        3.49
# 1    14.20        1.76               15.2       10.0        3.39
# 2    14.06        2.15               17.6      121.0        2.51
# 3    14.12        1.48               16.8       95.0        2.43
# 4    13.75        1.73               16.0       89.0        2.76
# 5    14.75        1.73               11.4       91.0        3.69
# 6    14.38        1.87               12.0      102.0        3.64
# 7    13.63        1.81               17.2      112.0        2.91
# 8    14.30        1.92               20.0      120.0        3.14
# 9    13.83        1.57               20.0      115.0        3.40
#
#    proanthocyanins   hue
# 0             2.18  0.86
# 1             1.97  1.05
# 2             1.25  1.06
# 3             1.57  1.17
# 4             1.81  1.15
# 5             2.81  1.25
# 6             2.96  1.20
# 7             1.46  1.28
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# #### Select the rows in which the alcohol value is greater than the mean.

# %%
alcohol_mean = wine['alcohol'].mean()
print(f'{alcohol_mean = }')

wine[wine['alcohol'] > alcohol_mean]
# Out:
# alcohol_mean = 12.93370588235294
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 1      14.20        1.76               15.2       10.0        3.39
# 2      14.06        2.15               17.6      121.0        2.51
# 3      14.12        1.48               16.8       95.0        2.43
# 4      13.75        1.73               16.0       89.0        2.76
# 5      14.75        1.73               11.4       91.0        3.69
# ..       ...         ...                ...        ...         ...
# 165    13.71        5.65               20.5       95.0        0.61
# 166    13.40        3.91               23.0      102.0        0.75
# 167    13.27        4.28               20.0      120.0        0.69
# 168    13.17        2.59               20.0      120.0        0.68
# 169    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 1               1.97  1.05
# 2               1.25  1.06
# 3               1.57  1.17
# ...

# %% [markdown]
# #### Select the rows in which any value is greater than the mean of its columns.

# %%
columns_mean = wine.mean()
columns_mean
# Out:
# alcohol              12.933706
# malic_acid            2.355353
# alcalinity_of_ash    19.653529
# magnesium            98.882353
# flavanoids            1.985235
# proanthocyanins       1.569353
# hue                   0.952388
# dtype: float64

# %%
# TODO: I still have to check that this solution is correct.

row_positions_to_select: list[int] = []

for row_position in range(wine.shape[0]):
    for column_position in range(wine.shape[1]):
        if wine.iloc[row_position, column_position] > columns_mean.iloc[column_position]:
            row_positions_to_select.append(row_position)
            break

wine.iloc[row_positions_to_select, :]
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      10.00        1.95               16.8      113.0        3.49
# 1      14.20        1.76               15.2       10.0        3.39
# 2      14.06        2.15               17.6      121.0        2.51
# 3      14.12        1.48               16.8       95.0        2.43
# 4      13.75        1.73               16.0       89.0        2.76
# ..       ...         ...                ...        ...         ...
# 165    13.71        5.65               20.5       95.0        0.61
# 166    13.40        3.91               23.0      102.0        0.75
# 167    13.27        4.28               20.0      120.0        0.69
# 168    13.17        2.59               20.0      120.0        0.68
# 169    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               2.18  0.86
# 1               1.97  1.05
# 2               1.25  1.06
# 3               1.57  1.17
# ...
